# %%
# import math
class Scientific_Calculator():
    def __init__(self,input1,input2):
        self.input1=input1
        self.input2=input2
    
    def addition(num1,num2):
        print("Addition: ", num1+num2)
    
    def subtraction(num1,num2):
        print("Subtraction: ", num1-num2)
    
    def multiplication(num1,num2):
        print("Multiplication: ", num1*num2)
        
    def division(num1,num2):
        print("Division: ", num1/num2)
    
    def sqrt(num1):
        print("Square Root: ", math.sqrt(num1))
    
    def square(num1):
        print("Square: ", math.pow(num1,2))
        
    def ceiling(num1):
        print("Ceiling: ",math.ceil(num1))
        
    def floor(num1):
        print("Floor: ", math.floor(num1))
    
    def cube(num1):
        print("Cube", math.pow(num1,3))
    
    def log(num1):
        print("Logarithm: ", math.log(num1))
    
    def factorial(num1):
        print("Factorial: ", math.factorial(num1))
    
    def gcd(num1,num2):
        print("Greatest Common Divisor: ",math.gcd(num1,num2))
    
    def hypot(num1,num2):
        print("Hypotenuse: ", math.hypot(num1,num2))
    
    def sin(num1):
        print("Sine: ", math.sin(num1))
    
    def radians(num1):
        print("Radians: ", math.radians(num1))
    
    def tan(num1):
        print("Tangent: ", math.tan(num1))
    
    def cos(num1):
        print("Cosine: ", math.cos(num1))
    
    def lcm(num1,num2):
        print("Least Common Multiple: ", math.lcm(num1,num2))
    
    def remainder(num1,num2):
        print("Remainder: ", math.remainder(num1,num2))
        
while True:
    print("1: Addition")
    print("2: Subtraction")
    print("3: Multiplication")
    print("4: Division")
    print("5: Square Root")
    print("6: Square")
    print("7: Ceiling")
    print("8: Floor")
    print("9: Cube")
    print("10: Logarithm")
    print("11: Factorial")
    print("12: Greatest Common Divisor")
    print("13: Hypotenuse")
    print("14: Sine")
    print("15: Radians")
    print("16: Tangent")
    print("17: Cosine")
    print("18: Least Common Multiple")
    print("19: Remainder")
    print("20: Exit")
    choice= int(input("Enter your Choice (1-20):"))
    
    if choice==1:
        num1=int(input("Enter the first number: "))
        num2=int(input("Enter the second number: "))
        Scientific_Calculator.addition(num1,num2)
    elif choice==2:
        num1=int(input("Enter the first number: "))
        num2=int(input("Enter the second number: "))
        Scientific_Calculator.subtraction(num1,num2)
    elif choice==3:
        num1=int(input("Enter the first number: "))
        num2=int(input("Enter the second number: "))
        Scientific_Calculator.multiplication(num1,num2)
    elif choice==4:
        num1=int(input("Enter the first number: "))
        num2=int(input("Enter the second number: "))
        if num2==0:
            print("Infinity")
        else:
            Scientific_Calculator.division(num1,num2)
    elif choice==5:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.sqrt(num1)
    elif choice==6:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.square(num1)
    elif choice==7:
        num1=float(input("Enter the number: "))
        Scientific_Calculator.ceiling(num1)
    elif choice==8:
        num1=float(input("Enter the number: "))
        Scientific_Calculator.floor(num1)
    elif choice==9:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.cube(num1)
    elif choice==10:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.log(num1)
    elif choice==11:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.factorial(num1)
    elif choice==12:
        num1=int(input("Enter the first number: "))
        num2=int(input("Enter the second number: "))
        Scientific_Calculator.gcd(num1,num2)
    elif choice==13:
        num1=int(input("Enter the perpendicular of triangle: "))
        num2=int(input("Enter the base of the triangle: "))
        Scientific_Calculator.hypot(num1,num2)
    elif choice==14:
        num1=float(input("Enter the number: "))
        Scientific_Calculator.sin(num1)
    elif choice==15:
        num1=int(input("Enter the angle in degrees: "))
        Scientific_Calculator.radians(num1)
    elif choice==16:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.tan(num1)
    elif choice==17:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.cos(num1)
    elif choice==18:
        num1=int(input("Enter the first number: "))
        num2=int(input("Enter the second number: "))
        Scientific_Calculator.lcm(num1,num2)
    elif choice==19:
        num1=int(input("Enter the first number: "))
        num2=int(input("Enter the second number: "))
        Scientific_Calculator.remainder(num1,num2)
    elif choice==20:
        break
    else:
        print("Wrong choice")
# Out:
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Square Root
# 6: Square
# 7: Ceiling
# 8: Floor
# 9: Cube
# 10: Logarithm
# 11: Factorial
# 12: Greatest Common Divisor
# 13: Hypotenuse
# 14: Sine
# 15: Radians
# 16: Tangent
# 17: Cosine
# 18: Least Common Multiple
# 19: Remainder
# 20: Exit
# Enter your Choice (1-20):7
# Enter the number: 6.7
# Ceiling:  7
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Square Root
# 6: Square
# 7: Ceiling
# 8: Floor
# 9: Cube
# 10: Logarithm
# 11: Factorial
# 12: Greatest Common Divisor
# 13: Hypotenuse
# 14: Sine
# 15: Radians
# 16: Tangent
# 17: Cosine
# 18: Least Common Multiple
# 19: Remainder
# 20: Exit
# Enter your Choice (1-20):18
# Enter the first number: 2
# Enter the second number: 6
# Least Common Multiple:  6
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Square Root
# 6: Square
# 7: Ceiling
# 8: Floor
# 9: Cube
# 10: Logarithm
# 11: Factorial
# 12: Greatest Common Divisor
# ...

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']
